# %%
pred_conditions = ['Left Ventricular Dysfunction' , 'ADHD', 'Birth Control', 'Opiate Dependence', 
   'Benign Prostatic Hyperplasia', 'Emergency Contraception', 'Bipolar Disorder', 
   'Epilepsy', 'Migraine', 'Depression', 'Crohns Disease', 'Cough', 'Obesity', 
   'Urinary Tract Infection', 'Fibromyalgia', 'Chronic Myelogenous', 'Leukemia', 
   'HIV', 'Insomnia', 'Rheumatoid', 'Arthritis,' 'Vaginal Yeast Infection',
   'Chlamydia Infection', 'Hirsutism', 'Panic Disorder', 'Migraine',
   'Irritable Bowel Syndrome', 'Osteoarthritis', 'Constipation', 'Bowel Preparation', 
   'Psychosis', 'Muscle Spasm', 'Hepatitis C', 'Overactive Bladder', 'Diabetes', 'Type 2 Asthma',
   'Lung Cancer', 'Schizophrenia', 'Dysuria', 'Smoking Cessation', 'Anxiety', 'Acne', 'male Infertility', 
   'Constipation', 'Acute Constipation', 'Drug Induced Erectile Dysfunction', 'Trigeminal Neuralgia',
   'Underactive Thyroid', 'Chronic Pain', 'Atrophic Vaginitis Skin', 'Structure Infection', 'Tinnitus',
   'Major Depressive Disorder', 'Anxiety', 'Stress', 'Rosacea', 'High Blood Pressure',
   'Restless Legs Syndrome', 'Osteolytic Bone', 'Metastases of Solid Tumors', 
   'Bronchitis', 'Skin or Soft Tissue Infection', 'Obsessive Compulsive Disorder', 
   'Endometriosis', 'Keratoconjunctivitis', 'Sicca Breakthrough', 'Pain', 'Seizures',
   'Neuropathic Pain Sedation', 'Menstrual Disorders', 'Allergic Rhinitis', 'Anesthesia', 
   'Undifferentiated Connective Tissue Disease', 'Diabetes', 'Type 1 Abnormal Uterine Bleeding', 
   'Weight Loss', 'Constipation', 'Chronic Breast Cancer', 'Metastatic Period Pain', 
   'Helicobacter Pylori Infection', 'Atrial Fibrillation', 'Uterine Fibroids', 'Kidney Infections', 
   'Generalized Anxiety Disorder', 'Asthma', 'Postmenopausal Symptoms', 'High Cholesterol', 'Hypogonadism', 
   'Male Hyperthyroidism', 'Back Pain', 'Anaplastic Oligodendroglioma', 'Sjogrens Syndrome', 'Asthma', 
   'acute Hot Flashes', 'Herpes', 'Simplex', 'Suppression Bacterial Infection', 'Bursitis', 'Diaper Rash', 
   'Systemic mastocytosis', 'Trichotillomania', 'Hashimotos disease', 'Eczema', 'Dental Abscess', 'Headache', 
   'Hypersomnia', 'Xerostomia', 'Breast Cancer', 'Sore Throat', 'Barretts Esophagus', 'Pain', 'Fever', 
   'Diverticulitis', 'Sinusitis', 'Polycystic Ovary Syndrome', 'Influenza', 'Hypothyroidism', 'Onychomycosis', 
   'Progesterone Insufficiency', 'GERD', 'Herpes', 'Simplex Gastroparesis Gout', 'Acute Motion Sickness', 
   'Multiple Sclerosis', 'Autism', 'Otitis Media', 'Upper Respiratory Tract Infection', 
   'Surgical Prophylaxis', 'Psoriatic Arthritis', 'Erosive Esophagitis', 
   'Premature Ventricular Depolarizations', 'Stomach Ulcer', 'Nausea', 'Vomiting', 'Light Anesthesia Angina', 
   'Pectoris Prophylaxis', 'Paranoid Disorder', 'Prostatitis', 'Extrapyramidal', 'Reaction', 'Anxiety',
    'Night Terrors', 'High Cholesterol', 'Familial Heterozygous', 'Spondyloarthritis', 
    'Clostridial Infection', 'Dermatomyositis', 'Bronchiectasis', 'Nasal Congestion', 
    'Benign Essential Trem', 'Angina', 'mometasone', 'Impeting Conjunctivitis', 
    'Post Traumatic Stress Disorder', 'Alcohol Withdrawal', 'Psoriasis', 'Cold', 'Sores', 
    'Hyperhidrosis', 'Ankylosing Spondylitis', 'Hemorrhoids' , 'Schizoaffective Disorder', 'Rhinitis', 
    'Oral Thrush', 'Hyperlipoproteinemia', 'Neutropenia', 'Osteoporosis', 
    'Reflex Sympathetic Dystrophy Syndrome', 'Urticaria Narcolepsy Systemic', 'Lupus Erythematosus', 
    'Ulcerative Colitis', 'Adult Human Growth Hormone Deficiency', 'Bacterial Vaginitis', 'COPD', 
    'Anorexia', 'TSH Suppression', 'Breast Cancer', 'Adjuvant Glaucoma', 'Cough', 'Nasal Congestion', 
    'Inflammatory Conditions', 'Urinary Incontinence' , 'Gout Bladder Infection', 'Human Papillomavirus', 
    'Prophylaxis', 'Glioblastoma', 'Multiforme', 'Strep Throat', 'Bacterial Skin Infection', 'Hereditary Angioedema', 'Cold', 'Labor Pain', 
                   'Dry Skin', 'Diabetes', 'Insipidus', 'Methicillin-Resistant Staphylococcus', 'Aureus Infection', 
                   'Borderline Personality Disorder', 'Amenorrhea', 'Pneumonia', 'Seborrheic', 'Dermatitis', 
                   'Interstitial, Cystitis', 'Malaria', 'Plaque', 'Psoriasis', 'Raynauds Syndrome', 'Addisons Disease', 
                   'Prostate Cancer', 'Allergies', 'Opioid-Induced Constipation', 'moterol', 'Diarrhea', 
                   'Seasonal Allergic Conjunctivitis', 'Opioid Overdose', 'Spondylolisthesis', 'Sleep Disorder', 
                   'Obstructive Sleep Apnea', 'Hypopnea Syndrome', 'Nausea', 'Vomiting',  'Mucositis', 'Ulcerative Colitis', 
                   'Active Head Lice', 'Tonsillitis', 'Pharyngitis', 'Pseudotumor', 'Cerebri', 'COPD', 'Ovarian Cysts', 
                   'Nightmares', 'Postherpetic Neuralgia', 'Conjunctivitis', 'Allergic', 'Atopic', 'Dermatitis', 'Diabetic', 
                   'Peripheral Neuropathy', 'Alcohol Dependence', 'Pharyngitis', 'Burns', 'External Crohns Disease', 
                   'Menorrhagia', 'Hypertriglyceridemia', 'Premenstrual Dysphoric Disorder', 'Urinary Tract Stones', 
                   'Seizure', 'Vertigo', 'Anemia', 'Chemotherapy Induced Glaucoma', 'Travelers Diarrhea', 'Dermatitis', 
                   'Hypodermoclysis', 'Muscle Pain', 'Pneumococcal Disease', 'Prophylaxis', 'Sexual Dysfunction', 'Occipital', 
                   'Neuralgia', 'Uveitis',  'Neuralgia', 'Deep Vein Thrombosis', 'Social Anxiety Disorder', 'Postpartum', 
                   'Depression', 'Light Sedation', 'Vitamin/Mineral Supplementation', 'Deficiency', 'Human Papilloma Virus', 
                   'Diarrhea', 'Chronic Nasal', 'Binge Eating Disorder', 'Dry Eye Disease', 'Chronic Fatigue Syndrome', 
                   'Allergic Reactions', 'Duodenal', 'Ulcer', 'Dermatologic Lesion', 'Alopecia', 'Edema', 'Actinic', 
                   'Keratosis', 'Strabismus', 'Hyperlipoproteinemia', 'Tinea', 'Pedis', 'Hyperparathyroidism', 
                   'Keratosis', 'Conjunctivitis', 'Osteoporosis', 'B12 Nutritional Deficiency', 'Granulomatosis', 
                   'Tourettes Syndrome', 'Dermatological Disorders', 'Parkinsons Disease', 'Precocious Puberty', 
                   'Juvenile', 'Rheumatoid Arthritis', 'Opiate Withdrawal', 'Onychomycosis', 'Fingernail Lipodystrophy',
                   'Renal Cell', 'Carcinoma', 'Heart Attack', 'Autoimmune', 'Hepatitis', 'Diabetic', 'Kidney Disease', 
                   'Menieres Disease', 'Vitamin D Deficiency', 'Sciatica', 'Myasthenia', 'Gravis Soft Tissue', 'Sarcoma', 'Giardiasis', 'Gastroenteritis', 'Alpha-1 Proteinase Inhibitor Deficiency', 'Crohns Disease', 'Acute Pulmonary Hypertension', 'Rat-bite', 'Fever', 'Warts', 'Leukemia', 'Stills Disease', 'Mitral Valve Prolapse', 'Peripheral Neuropathy', 'Cluster Headaches', 'Postoperative Pain', 'Tomography', 'Herpes', 'Zoster', 'Prophylaxis', 'Supraventricular Tachycardia', 'Indigestion','Nocturnal Leg Cramps','Anal Fissure', 'Fistula', 'Fatigue', 'Alzheimers Disease', 'Basal Cell Carcinoma']



aayu=[]
for data in pred_conditions:
    aayu.append(data)
    print(data)
print(aayu)
# Out:
# Left Ventricular Dysfunction
# ADHD
# Birth Control
# Opiate Dependence
# Benign Prostatic Hyperplasia
# Emergency Contraception
# Bipolar Disorder
# Epilepsy
# Migraine
# Depression
# Crohns Disease
# Cough
# Obesity
# Urinary Tract Infection
# Fibromyalgia
# Chronic Myelogenous
# Leukemia
# HIV
# Insomnia
# Rheumatoid
# Arthritis,Vaginal Yeast Infection
# Chlamydia Infection
# Hirsutism
# Panic Disorder
# Migraine
# Irritable Bowel Syndrome
# Osteoarthritis
# Constipation
# Bowel Preparation
# Psychosis
# Muscle Spasm
# Hepatitis C
# Overactive Bladder
# Diabetes
# Type 2 Asthma
# Lung Cancer
# Schizophrenia
# Dysuria
# Smoking Cessation
# Anxiety
# Acne
# male Infertility
# Constipation
# Acute Constipation
# Drug Induced Erectile Dysfunction
# Trigeminal Neuralgia
# Underactive Thyroid
# Chronic Pain
# Atrophic Vaginitis Skin
# Structure Infection
# Tinnitus
# Major Depressive Disorder
# Anxiety
# Stress
# Rosacea
# High Blood Pressure
# Restless Legs Syndrome
# Osteolytic Bone
# ...
